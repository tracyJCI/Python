# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets
import h5py

# %%
fn1 = "C:/Users/Kosi/Downloads/michigan_lld.flt"
michigan = np.fromfile(fn1, dtype='f4').reshape((5365, 4201))

# %%
michigan.shape
# Out:
# (5365, 4201)

# %%
plt.hist(michigan.flat)
# Out:
# (array([  285668.,        0.,        0.,        0.,        0.,        0.,
#                0.,        0.,        0., 22252697.]),
#  array([-9999.     , -8963.905  , -7928.8115 , -6893.717  , -5858.6226 ,
#         -4823.5283 , -3788.4338 , -2753.3396 , -1718.2452 ,  -683.1509 ,
#           351.94348], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
michigan.min()
# Out:
# -9999.0

# %%
michigan[michigan == -9999] = np.nan
np.nanmin(michigan), np.nanmax(michigan)
# Out:
# (-275.89, 351.94348)

# %%
michigan.min(), michigan.max()
# Out:
# C:\Users\Kosi\Anaconda3\lib\site-packages\numpy\core\_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# C:\Users\Kosi\Anaconda3\lib\site-packages\numpy\core\_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# (nan, nan)

# %%
plt.hist(michigan[~np.isnan(michigan)])
# Out:
# (array([4.305380e+05, 9.692900e+05, 2.736477e+06, 3.288539e+06,
#         4.979745e+06, 5.412426e+06, 2.916778e+06, 1.280268e+06,
#         2.349550e+05, 3.681000e+03]),
#  array([-275.89    , -213.10666 , -150.32332 ,  -87.53996 ,  -24.756617,
#           38.026733,  100.81008 ,  163.59343 ,  226.37679 ,  289.16013 ,
#          351.94348 ], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
#plt.style.use("classic")
#plt.imshow(michigan)
#plt.colorbar()

# %%
#plt.style.use("classic")
#plt.imshow(michigan)
#plt.clim(0, 300)
#plt.colorbar(extend = 'both')

# %%
#plt.imshow(michigan, cmap="seismic")
#plt.clim(-352, 352) 
#plt.colorbar()

# %%
plt.style.use("classic")
plt.imshow(michigan, cmap="Spectral")
plt.clim(-352,352)
plt.colorbar(extend = "both")

# %%
plt.style.use("seaborn")
plt.imshow(michigan, cmap="Accent")
plt.clim(-352, 352) 
plt.colorbar(extend = "both")

# %%
plt.style.use("classic")
plt.imshow(michigan, cmap = "nipy_spectral")
#plt.clim(-352, 352)
plt.colorbar(extend = "both")
